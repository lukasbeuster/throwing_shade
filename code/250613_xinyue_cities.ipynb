# %% [markdown]
# # Start

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('../data/raw_data/city_neighborhoods/belem_censitario_2022')
gdf.head()
# Out:
#             cd_recorte  quadro         cd_setor situacao cd_sit  \
# 0  6001150140275000317     600  150140275000317   Urbana      1
# 1  6001150140260000204     600  150140260000204   Urbana      1
# 2  6001150140260000205     600  150140260000205   Urbana      1
# 3  6001150140255000146     600  150140255000146   Urbana      1
# 4  6001150140255000147     600  150140255000147   Urbana      1
#
#                                           nm_situaca cd_tipo  \
# 0  b'c172656120757262616e6120646520616c7461206465...       0
# 1  b'c172656120757262616e6120646520616c7461206465...       0
# 2  b'c172656120757262616e6120646520616c7461206465...       0
# 3  b'c172656120757262616e6120646520616c7461206465...       1
# 4  b'c172656120757262616e6120646520616c7461206465...       1
#
#                        nm_tipo cd_uf        nm_uf sigla_uf   cd_mun  \
# 0  b'4ee36f20657370656369616c'    15  b'506172e1'       PA  1501402
# 1  b'4ee36f20657370656369616c'    15  b'506172e1'       PA  1501402
# ...

# %%
gdf.explore()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /data2/lukas/projects/throwing_shade/.shade_env/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File /data2/lukas/projects/throwing_shade/.shade_env/lib/python3.10/site-packages/folium/folium.py:336, in Map._repr_html_(self, **kwargs)
#     334     self._parent = None
#     335 else:
# --> 336     out = self._parent._repr_html_(**kwargs)
#     337 return out
#
# File /data2/lukas/projects/throwing_shade/.shade_env/lib/python3.10/site-packages/branca/element.py:369, in Figure._repr_html_(self, **kwargs)
#     367 def _repr_html_(self, **kwargs):
# ...

# %%
gdf.plot()
# Out:
# <Axes: >
