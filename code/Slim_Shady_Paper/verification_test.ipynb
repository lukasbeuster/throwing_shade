# %%
import rasterio as rio
from rasterio.crs import CRS
import matplotlib.pyplot as plt

# Specify the path to your raster file
raster_path = "/Users/michiel/Documents/code/SCL/images/Lukas/verification.tif"

# Load the raster data
with rio.open(raster_path) as src:
    # Read the first band (change index if needed)
    raster_bounds = src.bounds
    band1 = src.read(1)
    raster_transform = src.transform
    # Get metadata (optional)
    print(f"Raster CRS: {src.crs}")

# Plotting the raster data
plt.figure(figsize=(10, 6))
plt.imshow(band1) 
plt.title('Deepforest mask')
plt.show()
# Out:
# Raster CRS: EPSG:32631

# %%
import pandas as pd 
import geopandas as gpd
df2 = pd.read_csv('/Users/michiel/Documents/code/SCL/BOMEN.csv', delimiter = ';')
df2.head()
# Out:
#    OBJECTNUMMER      id                              soortnaam soortnaamKort  \
# 0             1  919934              Ulmus hollandica `Vegeta`         Ulmus
# 1             2  919935  Fraxinus excelsior `Westhof`s Glorie`      Fraxinus
# 2             3  919936               Ulmus glabra `Lutescens`         Ulmus
# 3             4  919937                          Quercus robur       Quercus
# 4             5  919939                Styphnolobium japonicum        Overig
#
#                        SoortnaamNL   soortnaamTop boomhoogteklasseActueel  \
# 0                   Huntingdon-iep    Iep (Ulmus)           b. 6 tot 9 m.
# 1     Gewone es (cultuurvariëteit)  Es (Fraxinus)          c. 9 tot 12 m.
# 2  Gele bergiep (cultuurvariëteit)    Iep (Ulmus)           b. 6 tot 9 m.
# 3                         Zomereik  Eik (Quercus)           b. 6 tot 9 m.
# 4                       Honingboom  Styphnolobium             a. tot 6 m.
#
#   stamdiameterklasse  jaarVanAanleg                  typeObject  \
# 0                NaN           1978  Boom niet vrij uitgroeiend
# 1     0,2 tot 0,3 m.           1990  Boom niet vrij uitgroeiend
# 2                NaN           2002  Boom niet vrij uitgroeiend
# 3                NaN           1985  Boom niet vrij uitgroeiend
# 4                NaN           2002  Boom niet vrij uitgroeiend
#
#   standplaatsGedetailleerd typeBeheerderPlus    typeEigenaarPlus  \
# 0                   Tegels    Stadsdeel Zuid  Gemeente Amsterdam
# 1                      NaN    Stadsdeel Zuid  Gemeente Amsterdam
# 2                      NaN    Stadsdeel Zuid  Gemeente Amsterdam
# 3                      NaN    Stadsdeel Zuid  Gemeente Amsterdam
# 4                      NaN    Stadsdeel Zuid  Gemeente Amsterdam
#
#                   WKT_LNG_LAT                 WKT_LAT_LNG       LNG        LAT
# 0  POINT(4.9026919 52.340093)  POINT(52.340093 4.9026919)  4.902692  52.340093
# 1  POINT(4.8552081 52.331984)  POINT(52.331984 4.8552081)  4.855208  52.331984
# 2  POINT(4.9036699 52.348837)  POINT(52.348837 4.9036699)  4.903670  52.348837
# 3   POINT(4.875886 52.341056)   POINT(52.341056 4.875886)  4.875886  52.341056
# 4  POINT(4.8803689 52.332891)  POINT(52.332891 4.8803689)  4.880369  52.332891

# %%
gdf2 = gpd.GeoDataFrame(
     df2,
     geometry=gpd.points_from_xy(df2['LNG'], df2['LAT']),
     crs = 'EPSG:4326'
     )

gdf2['geometry'] = gdf2['geometry'].to_crs(32631)

gdf2.crs
# Out:
# <Projected CRS: EPSG:32631>
# Name: WGS 84 / UTM zone 31N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 0°E and 6°E, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Andorra. Belgium. Benin. Burkina Faso. Denmark - North Sea. France. Germany - North Sea. Ghana. Luxembourg. Mali. Netherlands. Niger. Nigeria. Norway. Spain. Togo. United Kingdom (UK) - North Sea.
# - bounds: (0.0, 0.0, 6.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 31N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import rasterio as rio
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import box


# Create a bounding box from raster bounds
bbox = box(raster_bounds.left, raster_bounds.bottom, 
            raster_bounds.right, raster_bounds.top)



# Clip the GeoDataFrame to the bounding box
gdf_clipped = gdf2[gdf2.intersects(bbox)]

# Optionally transform CRS if necessary (to match raster)
gdf_clipped = gdf_clipped.to_crs(src.crs)

# Create a plot to visualize results
fig, ax = plt.subplots(figsize=(15, 9))

# Plot raster data
show(band1, ax=ax, cmap='gray', extent=rio.plot.plotting_extent(src))

# Plot clipped shapefile on top of raster
gdf_clipped.plot(ax=ax, color='red', markersize=1)

# Set titles and labels
plt.title('ADAM trees Overlay on deepforest mask')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# Save clipped shapefile if needed
# gdf_clipped.to_file("/path/to/save/clipped_shapefile.shp")  # Update path accordingly

# %%
def get_raster_value(point):
    x, y = point.x, point.y
    row, col = rio.transform.rowcol(raster_transform, x, y)
    return band1[row, col]

# Add a new column with extracted raster values
gdf_clipped['raster_value'] = gdf_clipped.geometry.apply(get_raster_value)


gdf_clipped.head()
# Out:
#        OBJECTNUMMER       id                   soortnaam soortnaamKort  \
# 44980         44981  1009239              Ulmus `Rebona`         Ulmus
# 44981         44982  1009240  Tilia cordata `Greenspire`         Tilia
# 44994         44995  1009285              Ulmus `Rebona`         Ulmus
# 44995         44996  1009286              Ulmus `Rebona`         Ulmus
# 45002         45003  1009297              Ulmus `Rebona`         Ulmus
#
#                           SoortnaamNL   soortnaamTop boomhoogteklasseActueel  \
# 44980          Iep (cultuurvariëteit)    Iep (Ulmus)           b. 6 tot 9 m.
# 44981  Winterlinde (cultuurvariëteit)  Linde (Tilia)           b. 6 tot 9 m.
# 44994          Iep (cultuurvariëteit)    Iep (Ulmus)           b. 6 tot 9 m.
# 44995          Iep (cultuurvariëteit)    Iep (Ulmus)           b. 6 tot 9 m.
# 45002          Iep (cultuurvariëteit)    Iep (Ulmus)           b. 6 tot 9 m.
#
#       stamdiameterklasse  jaarVanAanleg                  typeObject  \
# 44980                NaN              0  Boom niet vrij uitgroeiend
# 44981                NaN              0  Boom niet vrij uitgroeiend
# 44994                NaN              0  Boom niet vrij uitgroeiend
# 44995                NaN              0  Boom niet vrij uitgroeiend
# 45002                NaN              0  Boom niet vrij uitgroeiend
#
#       standplaatsGedetailleerd  typeBeheerderPlus    typeEigenaarPlus  \
# 44980           Straatbaksteen  Stadsdeel Centrum  Gemeente Amsterdam
# 44981           Straatbaksteen  Stadsdeel Centrum  Gemeente Amsterdam
# 44994           Straatbaksteen  Stadsdeel Centrum  Gemeente Amsterdam
# 44995           Straatbaksteen  Stadsdeel Centrum  Gemeente Amsterdam
# 45002                      NaN  Stadsdeel Centrum  Gemeente Amsterdam
#
#                       WKT_LNG_LAT                 WKT_LAT_LNG       LNG  \
# 44980    POINT(4.886081 52.36414)    POINT(52.36414 4.886081)  4.886081
# 44981  POINT(4.8894951 52.364101)  POINT(52.364101 4.8894951)  4.889495
# 44994     POINT(4.88771 52.36306)     POINT(52.36306 4.88771)  4.887710
# 44995   POINT(4.88762 52.3631339)   POINT(52.3631339 4.88762)  4.887620
# 45002   POINT(4.888014 52.362866)   POINT(52.362866 4.888014)  4.888014
#
#              LAT                        geometry  raster_value
# 44980  52.364140  POINT (628421.388 5803214.284)             0
# 44981  52.364101  POINT (628653.942 5803216.014)             0
# 44994  52.363060   POINT (628535.43 5803097.066)             0
# 44995  52.363134  POINT (628529.087 5803105.125)           255
# 45002  52.362866   POINT (628556.69 5803076.031)           255

# %%
print('percentage of trees detected:', (gdf_clipped['raster_value']==255).sum()/gdf_clipped.shape[0])
# Out:
# percentage of trees detected: 0.6987060998151571

# %%
# second method where I dont transform the raster
with rio.open('/Users/michiel/Documents/code/SCL/images/Lukas/verification.tif') as src:
    # Get the values at point locations
    gdf_clipped["rastervalue"] = [x[0] for x in src.sample(
        [(point.x, point.y) for point in gdf_clipped.geometry],
        indexes=1
    )]
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: path/to/your/raster.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[133], line 2
#       1 # second method where I dont transform the raster
# ----> 2 with rio.open('path/to/your/raster.tif') as src:
#       3     # Get the values at point locations
#       4     gdf_clipped["rastervalue"] = [x[0] for x in src.sample(
#       5         [(point.x, point.y) for point in gdf_clipped.geometry],
#       6         indexes=1
#       7     )]
#
# File ~/Documents/code/SCL/throwing_shade/lukas/lib/python3.9/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File ~/Documents/code/SCL/throwing_shade/lukas/lib/python3.9/site-packages/rasterio/__init__.py:356, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     353     path = _parse_path(raw_dataset_path)
#     355 if mode == "r":
# --> 356     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357 elif mode == "r+":
#     358     dataset = get_writer_for_path(path, driver=driver)(
#     359         path, mode, driver=driver, sharing=sharing, **kwargs
#     360     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: path/to/your/raster.tif: No such file or directory

# %%
print('percentage of trees detected:', (gdf_clipped['raster_value']==255).sum()/gdf_clipped.shape[0])
