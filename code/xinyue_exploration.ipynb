# %% [markdown]
# ### Exploration of Xinyue's data

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('../results/output/185567/185567_sidewalks_with_stats_multiple_dates.gpkg')

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.columns
# Out:
# Index(['allowed_turns', 'direction', 'index', 'layer', 'muv', 'road',
#        'speed_limit', 'type', 'width', '20250320_building_mean',
#        '20250320_building_std', '20250320_building_min',
#        '20250320_building_max', '20250320_building_shade_percent_at_0630',
#        '20250320_building_shade_percent_at_0700',
#        '20250320_building_shade_percent_at_0730',
#        '20250320_building_shade_percent_at_0800',
#        '20250320_building_shade_percent_at_0830',
#        '20250320_building_shade_percent_at_0900',
#        '20250320_building_shade_percent_at_0930',
#        '20250320_building_shade_percent_at_1000',
#        '20250320_building_shade_percent_at_1030',
#        '20250320_building_shade_percent_at_1100',
#        '20250320_building_shade_percent_at_1130',
#        '20250320_building_shade_percent_at_1200',
#        '20250320_building_shade_percent_at_1230',
#        '20250320_building_shade_percent_at_1300',
# ...

# %%
gdf.hist('20250320_tree_mean')
# Out:
# array([[<Axes: title={'center': '20250320_tree_mean'}>]], dtype=object)
